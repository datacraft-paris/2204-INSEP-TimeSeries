# %%
import pandas as pd
import seaborn as sns
import numpy as np
import datetime as dt

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.colors as clrs

from sklearn import preprocessing #ajout du numéro 

import time
import os

# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# Chargement des jeux de données
# ---

# %%
# !pip3 install pickle5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pickle5 in ./.local/lib/python3.6/site-packages (0.0.12)

# %%
import pickle5 as pickle

def load_df_pickle(fpath):
    with open(fpath, "rb") as fh:
      return pickle.load(fh)

# %%
t_start = time.time()

# df_ath1 = pd.read_pickle("/workspace/input/data/formatted/df_ath1_full.pkl")
# df_ath2 = pd.read_pickle("/workspace/input/data/formatted/df_ath2_full.pkl")
df_ath1 = load_df_pickle("data/df_ath1_full.pkl")
df_ath2 = load_df_pickle("data/df_ath2_full.pkl")

# df_morning_ath1 = pd.read_pickle("/workspace/input/data/formatted/df_ath1_morning.pkl")
# df_morning_ath2 = pd.read_pickle("/workspace/input/data/formatted/df_ath2_morning.pkl")
df_morning_ath1 = load_df_pickle("data/df_ath1_morning.pkl")
df_morning_ath2 = load_df_pickle("data/df_ath2_morning.pkl")

print(f"Time taken: {time.time()-t_start}")
# Out:
# Time taken: 1.3546080589294434

# %%
print("athlete 1")
print("df_ath1.shape          ", df_ath1.shape)
print("df_morning_ath1.shape  ", df_morning_ath1.shape)

print(" \n ----------------------------------------- \n ")

print("athlete 2")
print("df_ath2.shape          ", df_ath2.shape)
print("df_morning_ath2.shape  ", df_morning_ath2.shape)
# Out:
# athlete 1
# df_ath1.shape           (1040076, 28)
# df_morning_ath1.shape   (150, 20)
#
#  -----------------------------------------
#
# athlete 2
# df_ath2.shape           (903061, 28)
# df_morning_ath2.shape   (20, 20)

# %% [markdown]
# ---
#
# ## Regarder la complétion des données

# %%
# %run utils.ipynb
# %timeit df_completion(df_ath1, df_ath2)

df_completion(df_ath1, df_ath2)
# Out:
# <style  type="text/css" >
#     #T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03 th {
#           text-align: center;
#     }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row0_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row0_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row1_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row1_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row2_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row2_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row3_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row3_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row4_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row4_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row5_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row5_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row6_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row6_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row7_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row8_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row9_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row9_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row10_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row10_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row11_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row11_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row12_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row12_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row14_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row14_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row15_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row15_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row16_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row16_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row17_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row17_col1{
#             background-color:  #006837;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row7_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row8_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row18_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row19_col0{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row13_col0{
#             background-color:  #128a49;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row13_col1{
#             background-color:  #08773f;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row18_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row19_col1{
#             background-color:  #d1ec86;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row20_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row25_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row26_col0,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row27_col0{
#             background-color:  #f16640;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row20_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row21_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row26_col1,#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row27_col1{
#             background-color:  #73c264;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row21_col0{
#             background-color:  #e24731;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row22_col0{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row22_col1{
#             background-color:  #8ecf67;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row23_col0{
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row23_col1{
#             background-color:  #a9da6c;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row24_col0{
#             background-color:  #ee613e;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row24_col1{
#             background-color:  #8ccd67;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }#T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row25_col1{
#             background-color:  #96d268;
#             color:  #000000;
#             width:  100px;
#             text-align:  center;
#         }</style><table id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ath1</th>        <th class="col_heading level0 col1" >ath2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row0" class="row_heading level0 row0" >Timestamp</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row0_col1" class="data row0 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row1" class="row_heading level0 row1" >tps</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row1_col0" class="data row1 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row1_col1" class="data row1 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row2" class="row_heading level0 row2" >date</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row2_col0" class="data row2 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row2_col1" class="data row2 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row3" class="row_heading level0 row3" >training_counter</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row3_col0" class="data row3 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row3_col1" class="data row3 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row4" class="row_heading level0 row4" >day_index</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row4_col0" class="data row4 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row4_col1" class="data row4 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row5" class="row_heading level0 row5" >training_index</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row5_col0" class="data row5 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row5_col1" class="data row5 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03level0_row6" class="row_heading level0 row6" >type_ent</th>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row6_col0" class="data row6 col0" >100.0%</td>
#                         <td id="T_88fafb38_bbd5_11ec_a6e2_aeb5f63ddf03row6_col1" class="data row6 col1" >100.

# %% [markdown]
# ---
#
# # Répartition des différents entraînements

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18., 7.5), sharey=True)

df_loc = df_ath1.drop_duplicates(['date', 'type_ent'])
ax1.bar(df_loc['type_ent'].value_counts().index, df_loc['type_ent'].value_counts(), color="green")
for n,k in enumerate(df_loc['type_ent'].value_counts()):
    ax1.text(n, k+1, str(k), horizontalalignment = 'center', verticalalignment = 'center')
ax1.title.set_text("Répartition des types d'entrainement pour l'athlète 1")

df_loc = df_ath2.drop_duplicates(['date', 'type_ent'])
ax2.bar(df_loc['type_ent'].value_counts().index, df_loc['type_ent'].value_counts(), color="green")
for n,k in enumerate(df_loc['type_ent'].value_counts()):
    ax2.text(n, k+1, str(k), horizontalalignment = 'center', verticalalignment = 'center')
ax2.title.set_text("Répartition des types d'entrainement pour l'athlète 2")

ax1.set_ylabel("Type d'entrainements");

# %%
# %run utils.ipynb

dates_ath1 = df_ath1['date'].unique()
focus_on_training(df_ath1, list_dates=dates_ath1[:5])
# Out:
# Entraînement [1]:['endurance'], le 2021-03-27 avec 4041 points, de 16:02:36 à 17:09:56, durée = 0 days 01:07:20 - phase du cycle: ['Unknown']
# Entraînement [2]:['endurance'], le 2021-04-05 avec 6641 points, de 11:21:58 à 13:12:38, durée = 0 days 01:50:40 - phase du cycle: ['Folliculaire']
# Entraînement [3]:['endurance'], le 2021-04-07 avec 9023 points, de 13:24:57 à 15:55:19, durée = 0 days 02:30:22 - phase du cycle: ['Folliculaire']
# Entraînement [4]:['intensity'], le 2021-04-08 avec 3949 points, de 17:39:21 à 18:45:09, durée = 0 days 01:05:48 - phase du cycle: ['Folliculaire']
# Entraînement [5]:['endurance'], le 2021-04-10 avec 6812 points, de 13:45:38 à 15:39:09, durée = 0 days 01:53:31 - phase du cycle: ['Lutéale']

# %% [markdown]
# ---
#
# ## Regarder les corrélations dans les données
#
# #### Deux tableaux côte à côte pour les comparer

# %%
corr1 = df_ath1.corr(method='pearson')
corr2 = df_ath2.corr(method='pearson')


fig, ax = plt.subplots(1,2, figsize=(30, 10));

g1 = sns.heatmap(corr1, cmap='coolwarm', vmin=-1.0, vmax=1.0, ax=ax[0], square=True, annot=True, fmt=".2f");
g1.set_xticklabels(g1.get_xticklabels(), rotation=60, fontdict={"horizontalalignment":"right"});
g1.set_title(label='Correlations athlete 1', fontsize=20, loc='center', pad=10);

g2 = sns.heatmap(corr2, cmap='coolwarm', vmin=-1.0, vmax=1.0, ax=ax[1], square=True, annot=True, fmt=".2f");
g2.set_xticklabels(g2.get_xticklabels(), rotation=60, fontdict={"horizontalalignment":"right"});
g2.set_title(label='Correlations athlete 2', fontsize=20, loc='center', pad=10);

# %% [markdown]
# #### Un seul tableau à la fois, peut-être plus lisible

# %%
corr = df_ath2.corr(method='pearson')

fig, ax = plt.subplots(1,1, figsize=(26, 12));

g = sns.heatmap(corr, cmap='coolwarm', vmin=-1.0, vmax=1.0, ax=ax, square=True, annot=True, fmt=".2f");
g.set_xticklabels(g1.get_xticklabels(), rotation=60, fontdict={"horizontalalignment":"right"});
g.set_title(label='Correlations athlete', fontsize=20, loc='center', pad=10);

# %% [markdown]
# ---
#
# ## Filtrer le dataframe

# %%
print(df_ath1.columns.tolist())
# Out:
# ['Timestamp', 'tps', 'date', 'training_counter', 'day_index', 'training_index', 'type_ent', 'day_cycle', 'phase', 'activite', 'duree', 'kcal_cst', 'id', 'dist_totale_cst', 'mean_power', 'max_power', 'mean_hr', 'name', 'latitude', 'longitude', 'altitude', 'temperature', 'heart_rate', 'speed_meters_per_sec', 'power_watts', 'bike_cadence', 'distance_cumul', 'add_tps']

# %%
# %run utils.ipynb

df_exemple1 = filter_df(df_ath1, qtty="date", filtre={'kind':'include', 'list':["2021-06-09"]})
print(f"df_exemple1.shape : {df_exemple1.shape}")

df_exemple2 = filter_df(df_ath1, qtty="date", filtre={'kind':'exclude', 'list':["2021-06-09"]})
print(f"df_exemple2.shape : {df_exemple2.shape}")

df_exemple3 = filter_df(df_ath1, qtty="type_ent", filtre={'kind':'include', 'list':["endurance", "intensity"]})
print(f"df_exemple3.shape : {df_exemple3.shape}")
# Out:
# df_exemple1.shape : (17397, 28)
# df_exemple2.shape : (17397, 28)
# df_exemple3.shape : (849331, 28)

# %%
df_exemple1
# Out:
#                  Timestamp    tps        date  training_counter  day_index  \
# 365950 2021-06-09 13:54:52      1  2021-06-09                53         43
# 365951 2021-06-09 13:54:53      2  2021-06-09                53         43
# 365952 2021-06-09 13:54:54      3  2021-06-09                53         43
# 365953 2021-06-09 13:54:55      4  2021-06-09                53         43
# 365954 2021-06-09 13:54:56      5  2021-06-09                53         43
# ...                    ...    ...         ...               ...        ...
# 383342 2021-06-09 18:44:44  17393  2021-06-09                53         43
# 383343 2021-06-09 18:44:45  17394  2021-06-09                53         43
# 383344 2021-06-09 18:44:46  17395  2021-06-09                53         43
# 383345 2021-06-09 18:44:47  17396  2021-06-09                53         43
# 383346 2021-06-09 18:44:48  17397  2021-06-09                53         43
#
#         training_index   type_ent  day_cycle    phase     activite  ...  \
# 365950               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 365951               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 365952               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 365953               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 365954               1  endurance         22  Lutéale  ROAD_BIKING  ...
# ...                ...        ...        ...      ...          ...  ...
# 383342               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 383343               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 383344               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 383345               1  endurance         22  Lutéale  ROAD_BIKING  ...
# 383346               1  endurance         22  Lutéale  ROAD_BIKING  ...
#
#         latitude  longitude  altitude  temperature  heart_rate  \
# 365950    46.101      4.312     588.6         19.0       123.0
# 365951    46.101      4.312     588.0         19.0       123.0
# 365952    46.101      4.312     587.8         19.0       123.0
# 365953    46.101      4.312     587.0         19.0         NaN
# 365954    46.101      4.312     586.4         19.0       123.0
# ...          ...        ...       ...          ...         ...
# 383342    46.101      4.307     604.2         21.0       159.0
# 383343    46.101      4.307     604.2         21.0       159.0
# 383344    46.101      4.307     604.0         21.0       158.0
# 383345    46.101      4.307     603.8         21.0       157.0
# 383346    46.101      4.307     603.8         21.0       156.0
#
#         speed_meters_per_sec  power_watts bike_cadence  distance_cumul  \
# 365950                10.124          0.0          0.0          10.080
# 365951                10.133          0.0          0.0          20.090
# 365952                10.348          0.0          0.0          30.220
# 365953                10.469          0.0          0.0          40.640
# 365954                10.758          0.0          0.0          51.260
# ...                      ...          ...          ...             ...
# 383342                 4.787          0.0          0.0      124433.320
# 383343                 3.060          0.0          0.0      124437.078
# 383344                 1.791          0.0          0.0      124439.359
# 383345                 0.000          0.0          0.0      124440.617
# 383346                 0.000          0.0          0.0      124440.898
#
#         add_tps
# 365950      0.0
# 365951      0.0
# 365952      0.0
# 365953      0.0
# 365954      0.0
# ...         ...
# 383342      0.0
# 383343      0.0
# 383344      0.0
# 383345      0.0
# 383346      0.0
#
# [17397 rows x 28 columns]

# %% [markdown]
# ---
#
# # Quelques propositions de plots

# %%
# %run utils.ipynb

#C> - df_ath1["type_ent"].unique()   #C> --> ['endurance', 'intensity', 'recovery', 'race', 'warmup', 'test', 'ride', 'nan']
list_valeurs = ["intensity", "race"]

for train in list_valeurs:
    df_reduced = filter_df(df_ath1, qtty="type_ent", filtre={'kind':'include', 'list':[train]})
    print(f"Entraînement: {train} - # de date {len(df_reduced['date'].unique())} - # de points : {len(df_reduced)}")

    plot_df(df_reduced, qtty_x='heart_rate', qtty_y='power_watts', groupby='date', figtitle=train, tuple_figsize=(18.,8.))
# Out:
# Entraînement: intensity - # de date 27 - # de points : 129572
# Entraînement: race - # de date 14 - # de points : 122586

# %% [markdown]
# ---
#
# ## Comparer différentes valeurs pour un entraînement, ou sur plusieurs entraînement

# %%
# %run utils.ipynb


list_dates = ['2021-05-03', '2021-05-15'] #, '2021-06-05', '2021-06-11', '2021-06-30', '2021-07-30', '2021-07-31', '2021-08-20']

list_to_plot = ["heart_rate", "bike_cadence", "power_watts"]#, "altitude", "temperature"]

for ctr, date in enumerate(list_dates):
    df_reduced = filter_df(df_ath1, qtty="date", filtre={'kind':'include', 'list':[date]})

    plot_df_1day_time_series(df_reduced, x_qtty="Timestamp", qtties_plot=list_to_plot, tuple_figsize=(22.,6.), shade_area=True)

# %% [markdown]
# ---
#
# ## Get dataframe formatted for time series investigation

# %%
# %run utils.ipynb

time_series = ['latitude', 'longitude', 'altitude', 'temperature', 'heart_rate', 'speed_meters_per_sec', 'power_watts', 'bike_cadence', 'distance_cumul']

df_ath1_ts = make_df_timeseries(df_ath1, qtties=time_series)
